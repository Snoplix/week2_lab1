# %% [markdown]
# <a href="https://colab.research.google.com/github/Snoplix/week2_lab1/blob/main/PART_B_Learning_Paradigms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PART B: Learning Paradigms in Machine Learning
#
# **Course:** Introduction to AI & Machine Learning
# **Lecture Companion:** Supervised vs Unsupervised Learning
#
# In this lab, we connect **lecture concepts** to **hands-on examples**.
#
# You will learn the differences between:
# - Supervised Learning → Regression
# - Supervised Learning → Classification
# - Unsupervised Learning → Clustering
#
# Each section includes intuition, code, and exercises.

# %% [markdown]
# ## Learning Paradigms Overview
#
# | Learning Type | Data Labels | Output Type | Example |
# |-------------|------------|-------------|---------|
# | Supervised (Regression) | Yes | Continuous | House price |
# | Supervised (Classification) | Yes | Discrete | Rain or No Rain |
# | Unsupervised | No | Groups / Patterns | Customer clusters |

# %% [markdown]
# ## 1. Supervised Learning – Regression
#
# **Goal:** Predict a numerical value.
#
# **Example:** Predict house price from area.
#
# We already know the *correct prices* during training.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

areas = np.array([50, 70, 90, 110, 130])
prices = np.array([25000, 35000, 45000, 55000, 65000])

X = areas.reshape(-1, 1)
y = prices

model = LinearRegression()
model.fit(X, y)

print("Predicted price for 100 m²:", model.predict([[100]])[0])
# Out:
# Predicted price for 100 m²: 50000.0

# %% [markdown]
# ### ✏️ Exercise 1: Regression Practice
#
# 1. Change the training data
# 2. Predict prices for houses of area 80 and 140

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# TODO: modify areas and prices
areas = np.array([50, 70, 90, 110, 130])
prices = np.array([25000, 35000, 45000, 55000, 65000])

# TODO: train model
X = areas.reshape(-1, 1)
y = prices

model = LinearRegression()
model.fit(X, y)

# TODO: predictions
print("Predicted price for 80 m²:", model.predict([[80]]))
print("Predicted price for 140 m²:", model.predict([[140]]))
# Out:
# Predicted price for 80 m²: [40000.]
# Predicted price for 140 m²: [70000.]

# %% [markdown]
# ## 2. Supervised Learning – Classification
#
# **Goal:** Predict a category or class.
#
# **Example:** Will it rain or not?
#
# - 1 → Rain
# - 0 → No Rain

# %%
from sklearn.linear_model import LogisticRegression

# Features: humidity (%), temperature (°C)
X = np.array([
    [80, 20],
    [90, 18],
    [60, 25],
    [30, 30],
    [85, 19]
])

# Labels: 1 = Rain, 0 = No Rain
y = np.array([1, 1, 0, 0, 1])

clf = LogisticRegression()
clf.fit(X, y)

prediction = clf.predict([[75, 22]])
print("Will it rain?", "Yes" if prediction[0] == 1 else "No")
# Out:
# Will it rain? Yes

# %% [markdown]
# ### ✏️ Exercise 2: Classification Practice
#
# 1. Add two more weather samples
# 2. Predict rain for different humidity/temperature values

# %%
from sklearn.linear_model import LogisticRegression
import numpy as np

# TODO: extend X and y
X = np.array([
    [80, 20],
    [90, 18],
    [60, 25],
    [30, 30],
    [85, 19],
    [70, 23],
    [40, 28]
])

# Labels: 1 = Rain, 0 = No Rain
y = np.array([1, 1, 0, 0, 1, 1, 0])

# TODO: train classifier
clf = LogisticRegression()
clf.fit(X, y)

# TODO: predictions
print("Prediction for [60, 24]", "Rain" if clf.predict([[60, 24]])[0] == 1 else "No Rain")
print("Prediction for [90, 17]", "Rain" if clf.predict([[90, 17]])[0] == 1 else "No Rain")
# Out:
# Prediction for [60, 24] No Rain
# Prediction for [90, 17] Rain

# %% [markdown]
# ## 3. Unsupervised Learning – Clustering
#
# **Goal:** Discover patterns without labels.
#
# **Example:** Group houses by size and price.
#
# No correct answers are given to the algorithm.

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = np.array([
    [50, 25000],
    [60, 30000],
    [120, 60000],
    [130, 65000],
    [80, 40000]
])

kmeans = KMeans(n_clusters=2, random_state=0)
clusters = kmeans.fit_predict(data)

plt.scatter(data[:,0], data[:,1], c=clusters)
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("House Clusters")
plt.show()

# %% [markdown]
# ### ✏️ Exercise 3: Clustering Practice
#
# 1. Change number of clusters to 3
# 2. Add more house data points
# 3. Observe how clusters change

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

data = np.array([
    [50, 25000],
    [60, 30000],
    [70, 55555],
    [140, 80000],
    [120, 60000],
    [130, 65000],
    [80, 40000]
])


# TODO: clustering
kmeans = KMeans(n_clusters= 3, random_state=0)
clusters = kmeans.fit_predict(data)

plt.scatter(data[:,0], data[:,1], c=clusters)
plt.xlabel("Area")
plt.ylabel("Price")
plt.title("Clusters")
plt.show()

# %% [markdown]
# ## Final Comparison
#
# - **Regression:** predict numbers (house prices)
# - **Classification:** predict classes (rain / no rain)
# - **Clustering:** find groups (no labels)
#
# These three ideas cover **most ML problems** you will encounter.
